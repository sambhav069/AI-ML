# %%
import pandas as pd

# %%
df=pd.read_csv(r"E:\aiml training\Used_Bikes.csv")

# %%
#question 1
nyi=df[(df["brand"]== "KTM")&(df["city"]=="Jaipur")  ] 
print(nyi)
print("number of bikes in jaipur are:",nyi.shape)
print("the min price of bike is:",nyi[["price"]].min())
# Out:
#            bike_name     price    city  kms_driven        owner  age  power  \
# 888     KTM RC 390cc  147000.0  Jaipur     15000.0  First Owner  6.0  390.0
# 4945  KTM Duke 390cc  200000.0  Jaipur     11700.0  First Owner  4.0  390.0
# 4948    KTM RC 390cc  175000.0  Jaipur     10880.0  First Owner  4.0  390.0
# 6073    KTM RC 200cc  190000.0  Jaipur      7902.0  First Owner  2.0  200.0
# 6159  KTM Duke 250cc  135000.0  Jaipur     12507.0  First Owner  4.0  250.0
# 6552    KTM RC 200cc  190000.0  Jaipur      7902.0  First Owner  2.0  200.0
# 6734    KTM RC 200cc  128000.0  Jaipur     15000.0  First Owner  4.0  200.0
# 7561  KTM Duke 250cc  150000.0  Jaipur     12500.0  First Owner  4.0  250.0
#
#      brand
# 888    KTM
# 4945   KTM
# 4948   KTM
# 6073   KTM
# 6159   KTM
# 6552   KTM
# 6734   KTM
# 7561   KTM
# number of bikes in jaipur are: (8, 8)
# the min price of bike is: price    128000.0
# dtype: float64

# %%
#question 2
nyi=df[(df["city"]== "Delhi")&(df["owner"]== "First Owner")   ] 
print(nyi.shape)
print(nyi[["age"]].max())
print(nyi[["age"]].min())
# Out:
# (6516, 8)
# age    20.0
# dtype: float64
# age    1.0
# dtype: float64

# %%
#question 3
import xlrd

df=pd.read_excel(r"E:\aiml training\IV Sem- Sitting Arrangement- Master section-wise & room-wise- Student Display.xlsx")
df
# Out:
#        Jaipur Engineering College and Research Centre Unnamed: 1  Unnamed: 2  \
# 0   Department of Computer Science and Engineering...        NaN         NaN
# 1                     IV Semester Sitting Arrangement        NaN         NaN
# 2                                                 NaN        NaN         NaN
# 3                                                 NaN        NaN        4CSA
# 4                                                 NaN        NaN        FROM
# 5                                                   1       LT-1  22EJCCS001
# 6                                                   2       LT-2  22EJCCS029
# 7                                                   3       LT-3  22EJCCS057
# 8                                                   4       LT-4         NaN
# 9                                                   5      BS-01         NaN
# 10                                                  6      BS-08         NaN
# ...
